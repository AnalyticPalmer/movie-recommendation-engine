# %%
from src.recommenders.popularity import PopularityRecommender

model = PopularityRecommender(
    min_ratings=50
)

model.fit()

recommendations = model.recommend(
    top_k=10
)

recommendations
# Out:
#      movie_id                             title  rating_count  average_rating  \
# 272       318           Schindler's List (1993)           297        4.468013
# 51         64  Shawshank Redemption, The (1994)           281        4.444840
# 375       483                 Casablanca (1942)           242        4.454545
# 38         50                  Star Wars (1977)           580        4.358621
# 10         12        Usual Suspects, The (1995)           265        4.392453
# 446       603                Rear Window (1954)           207        4.386473
# 102       127             Godfather, The (1972)           409        4.283619
# 81         98  Silence of the Lambs, The (1991)           385        4.285714
# 320       408             Close Shave, A (1995)           112        4.491071
# 140       169        Wrong Trousers, The (1993)           118        4.466102
#
#      weighted_score
# 272        4.333016
# 51         4.306817
# 375        4.296426
# 38         4.292947
# 10         4.255735
# 446        4.220064
# 102        4.201648
# 81         4.198980
# 320        4.194793
# 140        4.187836
